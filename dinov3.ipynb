# %% [markdown]
# # Setup

# %%
# clone repo
# !git clone https://github.com/KhangDaoz/dinov3.git
# %cd dinov3
# !python -m pip install -r requirements.txt

# extract dataset
import tarfile
import os

tar_path = "/kaggle/input/datasets/khangdaoz/cub-200-2011/CUB_200_2011.tgz"
extract_path = "/kaggle/working/dinov3/data"

os.makedirs(extract_path, exist_ok=True)

with tarfile.open(tar_path, "r:gz") as tar:
    tar.extractall(
        path=extract_path,
        filter="data"
    )

print("Đã giải nén vào:", extract_path)
print(os.listdir(extract_path))

# import hf key
import os
from kaggle_secrets import UserSecretsClient

os.environ["HF_TOKEN"] = UserSecretsClient().get_secret("HF_TOKEN")

# %% [markdown]
# # Run e1

# %%
# !python scripts/run_e1.py --config configs/cub_e1.yaml --test

# zip output file
import shutil

folder = "/kaggle/working/dinov3/outputs/e1_evidential"
output_zip = "/kaggle/working/e1_evidential"

shutil.make_archive(
    output_zip,
    "zip",
    folder
)

print("Created:", output_zip + ".zip")

# %% [markdown]
# # Run e2

# %% [markdown]
# ## e2a-m1

# %%
# !python scripts/run_e2a.py \
    --config configs/cub_e2a_m1.yaml \
    --stage validation

# zip output file
import shutil

folder = "/kaggle/working/dinov3/outputs/e2a_cls"
output_zip = "/kaggle/working/e2a_cls"

shutil.make_archive(
    output_zip,
    "zip",
    folder
)

print("Created:", output_zip + ".zip")

# %% [markdown]
# ## e2a-m2

# %%
# !python scripts/run_e2a.py \
      --config configs/cub_e2a_m2.yaml \
      --stage validation

# zip output file
import shutil

folder = "/kaggle/working/dinov3/outputs/e2a_mean_patch"
output_zip = "/kaggle/working/e2a_mean_patch"

shutil.make_archive(
    output_zip,
    "zip",
    folder
)

print("Created:", output_zip + ".zip")

# %% [markdown]
# ## e2a-m3

# %%
# !python scripts/run_e2a.py \
      --config configs/cub_e2a_m3.yaml \
      --stage validation

# zip output file
import shutil

folder = "/kaggle/working/dinov3/outputs/e2a_fusion"
output_zip = "/kaggle/working/e2a_fusion"

shutil.make_archive(
    output_zip,
    "zip",
    folder
)

print("Created:", output_zip + ".zip")

# %% [markdown]
# ## e2a-m4

# %%
# !python scripts/run_e2a.py \
      --config configs/cub_e2a_m4.yaml \
      --stage validation

# zip output file
import shutil

folder = "/kaggle/working/dinov3/outputs/e2a_attention_pool"
output_zip = "/kaggle/working/e2a_attention_pool"

shutil.make_archive(
    output_zip,
    "zip",
    folder
)

print("Created:", output_zip + ".zip")

# %% [markdown]
# ## e2a-final

# %%
# !python scripts/run_e2a_test_selection.py --configs \
    configs/cub_e2a_m1.yaml \
    configs/cub_e2a_m2.yaml \
    configs/cub_e2a_m3.yaml \
    configs/cub_e2a_m4.yaml

# zip output file
import shutil

folder = "/kaggle/working/dinov3/outputs/e2a_selection"
output_zip = "/kaggle/working/e2a_selection"

shutil.make_archive(
    output_zip,
    "zip",
    folder
)

print("Created:", output_zip + ".zip")

# %% [markdown]
# # e2b

# %%
# !python scripts/run_e2b.py --config configs/cub_e2b.yaml --stage validation
# !python scripts/run_e2b.py --config configs/cub_e2b.yaml --stage test

# zip output file
import shutil

folder = "/kaggle/working/dinov3/outputs/e2b_pair_confidence"
output_zip = "/kaggle/working/e2b_pair_confidence"

shutil.make_archive(
    output_zip,
    "zip",
    folder
)

print("Created:", output_zip + ".zip")
